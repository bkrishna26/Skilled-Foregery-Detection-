# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/7/H-S-7-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/135/H-S-135-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/47/H-S-47-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/17/H-S-017-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/81/H-S-81-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/19/H-S-19-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/121/H-S-121-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/22/H-S-22-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-17.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-28.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-24.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-09.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-30.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-18.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-05.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-08.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-15.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-10.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-25.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-F-27.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/2/H-S-2-G-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-03.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-07.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-23.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-01.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-14.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-20.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-04.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-26.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-16.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-02.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-21.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-19.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-22.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-13.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-11.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-12.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-G-06.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-29.tif
# /kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/147/H-S-147-F-10.tif
# ...
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/forgeries_33_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/original_33_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/original_33_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/forgeries_33_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/original_33_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/forgeries_33_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/forgeries_33_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/forgeries_33_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/forgeries_33_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/33/forgeries_33_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_23.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_23.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/forgeries_54_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/54/original_54_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_23.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_23.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/original_48_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/48/forgeries_48_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_23.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_23.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/forgeries_29_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/29/original_29_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_11.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_7.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_16.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_8.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_21.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_20.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_14.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_3.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_6.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_10.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_5.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_23.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_22.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_24.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_13.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_2.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_18.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_15.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_9.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_1.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/original_24_17.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_12.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_19.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_4.png
# /kaggle/input/handwritten-signature-datasets/CEDAR/CEDAR/24/forgeries_24_23.png

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Define the path containing both real and forged signatures
signatures_path = "/kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi/1"
def display_images_from_folder(folder_path, num_images=10):
    """Display real and forged images from a specified folder."""
    images = os.listdir(folder_path)  # Get all images in the folder
    
    real_images = [img for img in images if "G" in img]  # Filter images with "G" (Genuine/Real)
    forged_images = [img for img in images if "F" in img]  # Filter images with "F" (Forged)

    plt.figure(figsize=(15, 10))  # Adjust figure size as needed
    
    # Display a specified number of real and forged images
    for i, (real_img, forged_img) in enumerate(zip(real_images[:num_images], forged_images[:num_images])):
        # Display real signature
        real_img_path = os.path.join(folder_path, real_img)
        real_img_data = cv2.imread(real_img_path)
        
        if real_img_data is not None:
            real_img_data = cv2.resize(real_img_data, (299, 299))  # Resize if necessary
            plt.subplot(2, num_images, i + 1)
            plt.imshow(cv2.cvtColor(real_img_data, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.title("Real Signature")
        
        # Display forged signature
        forged_img_path = os.path.join(folder_path, forged_img)
        forged_img_data = cv2.imread(forged_img_path)
        
        if forged_img_data is not None:
            forged_img_data = cv2.resize(forged_img_data, (299, 299))  # Resize if necessary
            plt.subplot(2, num_images, i + 1 + num_images)  # Adjust subplot index for the second row
            plt.imshow(cv2.cvtColor(forged_img_data, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.title("Forged Signature")
    
    plt.tight_layout()  # Adjust layout
    plt.show()

# Display real and forged signatures from the same folder
display_images_from_folder(signatures_path, num_images=10)

# %%
import os
import matplotlib.pyplot as plt

# Define the path where images are stored (both real and forged)
train_path = "/kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi"

def count_images_in_classes(base_path):
    """Count the number of real and forged images based on filename logic."""
    real_count = 0
    forged_count = 0
    
    # Iterate through all the files in the base directory
    for folder_name in os.listdir(base_path):
        folder_path = os.path.join(base_path, folder_name)
        if os.path.isdir(folder_path):
            # Iterate through images in each folder
            for img_name in os.listdir(folder_path):
                # Check if the image name contains 'G' (Real) or 'F' (Forged)
                if 'G' in img_name:  
                    real_count += 1
                elif 'F' in img_name:  
                    forged_count += 1
    
    return real_count, forged_count

# Get counts of real and forged signatures
real_count, forged_count = count_images_in_classes(train_path)

# Visualization
classes = ['Real', 'Forged']
counts = [real_count, forged_count]

plt.figure(figsize=(8, 5))
plt.bar(classes, counts, color=['blue', 'red'])
plt.title('Number of Instances in Each Class (Real vs Forged)')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjust layout
plt.show()

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns
import tensorflow as tf

# Check if GPU is available and set it as the default device
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Set memory growth for GPU
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Using GPU:", gpus)
    except RuntimeError as e:
        print(e)

# Parameters
IMG_SIZE = 299  # Xception input size
BATCH_SIZE = 32
EPOCHS = 10
max_images_per_class = 20 # Limit the number of images loaded per class (set a lower number if needed)

# Load dataset with limited number of images
def load_dataset(dataset_path, max_images_per_class):
    images = []
    labels = []
    
    for folder_name in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder_name)
        if os.path.isdir(folder_path):
            # Iterate over images in the folder
            file_list = os.listdir(folder_path)[:max_images_per_class]  # Cap the number of files loaded
            for file_name in file_list:
                file_path = os.path.join(folder_path, file_name)
                img = cv2.imread(file_path)
                if img is not None:  # Check if image is loaded correctly
                    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                    img = img / 255.0  # Normalize the image
                    # Classify based on 'G' (genuine/real) or 'F' (forged) in filename
                    if 'G' in file_name:
                        label = 1  # Genuine/Real
                    elif 'F' in file_name:
                        label = 0  # Forged
                    else:
                        continue  # Skip if neither 'G' nor 'F' in the filename
                    images.append(img)
                    labels.append(label)
    
    return np.array(images), np.array(labels)

# Load all images from the dataset
images, labels = load_dataset("/kaggle/input/handwritten-signature-datasets/BHSig260-Hindi/BHSig260-Hindi", max_images_per_class)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Model architecture
base_model = Xception(include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(1024, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

# Compile the model
model.compile(optimizer=RMSprop(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

# Training the model with limited images
history = model.fit(train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
                    validation_data=(X_test, y_test),
                    epochs=EPOCHS,
                    batch_size=BATCH_SIZE)

# Evaluate the model on the test set
y_pred = (model.predict(X_test) > 0.5).astype("int32").flatten()

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Forged', 'Real'], yticklabels=['Forged', 'Real'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Using GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729739252.424668     392 service.cc:145] XLA service 0x7b7660013c50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729739252.424746     392 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1729739252.424753     392 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 2024-10-24 03:07:46.369736: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[32,128,147,147]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,147,147]{3,2,1,0}, f32[128,128,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-10-24 03:07:46.511649: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.142069567s
# Trying algorithm eng3{k11=2} for conv (f32[32,128,147,147]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,147,147]{3,2,1,0}, f32[128,128,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# I0000 00:00:1729739302.113330     392 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 145s 902ms/step - accuracy: 0.7212 - loss: 0.5542 - val_accuracy: 0.7516 - val_loss: 0.5043
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 73s 836ms/step - accuracy: 0.8607 - loss: 0.3455 - val_accuracy: 0.8313 - val_loss: 0.4048
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 73s 839ms/step - accuracy: 0.9017 - loss: 0.2422 - val_accuracy: 0.6891 - val_loss: 0.8842
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 74s 854ms/step - accuracy: 0.9083 - loss: 0.2111 - val_accuracy: 0.8250 - val_loss: 0.5133
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 78s 894ms/step - accuracy: 0.9241 - loss: 0.1832 - val_accuracy: 0.8156 - val_loss: 0.5849
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 75s 863ms/step - accuracy: 0.9552 - loss: 0.1250 - val_accuracy: 0.8828 - val_loss: 0.3226
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 77s 881ms/step - accuracy: 0.9551 - loss: 0.1095 - val_accuracy: 0.9109 - val_loss: 0.2610
# Epoch 8/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 77s 883ms/step - accuracy: 0.9657 - loss: 0.0951 - val_accuracy: 0.8844 - val_loss: 0.4578
# Epoch 9/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 75s 855ms/step - accuracy: 0.9639 - loss: 0.0917 - val_accuracy: 0.8625 - val_loss: 0.4501
# Epoch 10/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 74s 853ms/step - accuracy: 0.9743 - loss: 0.0701 - val_accuracy: 0.9391 - val_loss: 0.2014
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step
# Accuracy: 0.9391
# Precision: 0.9524
# Recall: 0.9180
# F1 Score: 0.9349

# %%
def plot_training_history(history):
    # Plotting accuracy
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plotting loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_training_history(history)
